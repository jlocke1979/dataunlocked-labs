# %% [markdown]
# ## Data Overview
# Text

# %% [markdown]
# ## Key Observations
# Text

# %%
# Debugging File Path
import sys
print(sys.executable)
# Out:
# /Users/justinlocke/Documents/GitHub/dataunlocked-labs/.venv/bin/python

# %%
# !pip install pandas
# !pip install plotly kaleido
# !pip install matplotlib
# %pip install python-pptx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing Libraries In steps to identify any issues with the imports.

import pandas as pd
print("pandas ok")

import plotly.express as px
print("plotly.express ok")


from pathlib import Path
print("pathlib ok")

from IPython.display import display, Markdown
print("ipython display ok")

from pptx import Presentation
print("pptx ok")


from pptx.dml.color import RGBColor
print("pptx.dml.color    ok")

from pptx.enum.shapes import MSO_SHAPE
print("pptx.enum.shapes    ok")


from pptx.util import Inches, Pt
print("pptx.enum.shapes    ok")
# Out:
# pandas ok
# plotly.express ok
# pathlib ok
# ipython display ok
# pptx ok
# pptx.dml.color    ok

# %%
# Importing Libraries In steps to identify any issues with the imports.

# import numpy as np
# print("numpy ok")

# %%
# Importing Libraries In steps to identify any issues with the imports.

# import kaleido  
# print("kaleido ok")

# %%
# Importing Libraries In steps to identify any issues with the imports.

import numpy as np
print("numpy ok")
# Out:
# numpy ok

# %%
# Importing Libraries In steps to identify any issues with the imports.

# import matplotlib.pyplot as plt
# print("matplotlib.pyplot ok")

# %%
# Importing Libraries In steps to identify any issues with the imports.

# from matplotlib.colors import ListedColormap
# print("matplotlib.colors ok")

# %% [markdown]
# Source 1) OPTN Portal
# The raw dataset is exported in a wide, tab-delimited format intended for human readability rather than analysis.
#
# Key issues observed:
# - Year values are spread across multiple columns
# - Numeric values are stored as strings with formatting (e.g., "1 077 213")
# - Rows include hierarchical labels and inconsistent structure
# - Missing values and irregular spacing are present
#
# This format requires restructuring and cleaning before it can be used for analysis or visualization.

# %%
df = pd.read_csv("../data/processed/transplants_treemap.csv")
df.head(10)
# Out:
#        donor_type              organ  transplants
# 0  Deceased Donor             Kidney       435931
# 1  Deceased Donor              Liver       227319
# 2    Living Donor             Kidney       196381
# 3  Deceased Donor              Heart       102209
# 4  Deceased Donor               Lung        59258
# 5  Deceased Donor  Kidney / Pancreas        29548
# 6    Living Donor              Liver        11147
# 7  Deceased Donor           Pancreas         9600
# 8  Deceased Donor          Intestine         3611
# 9  Deceased Donor       Heart / Lung         1641

# %%
df.columns
# Out:
# Index(['donor_type', 'organ', 'transplants'], dtype='str')

# %% [markdown]
# ## Transformation Summary
#
# The dataset was transformed from a wide, formatted report into a structured tabular format.
#
# Key steps included:
# - Extracting organ categories
# - Converting formatted strings to numeric values
# - Reshaping year-based columns into a usable structure
# - Standardizing field names
#
# The cleaned dataset enables direct comparison across organ categories and supports the categorical visualization.

# %% [markdown]
# # 1. Basic structure check

# %%
print("Dataset shape:")
print(df.shape)

print("\nColumns:")
print(df.columns.tolist())

print("\nData types:")
print(df.dtypes)
# Out:
# Dataset shape:
# (22, 3)
#
# Columns:
# ['donor_type', 'organ', 'transplants']
#
# Data types:
# donor_type       str
# organ            str
# transplants    int64
# dtype: object

# %% [markdown]
# # 2. Missing values check

# %%
print("\nMissing values:")
print(df.isna().sum())
# Out:
# Missing values:
# donor_type     0
# organ          0
# transplants    0
# dtype: int64

# %%
# 3. Summary by organ
organ_summary = (
    df.groupby("organ", as_index=False)["transplants"]
    .sum()
    .sort_values("transplants", ascending=False)
)

# %%
print("\nTotal transplants by organ:")
display(organ_summary)

# 4. Summary by donor type
donor_type_summary = (
    df.groupby("donor_type", as_index=False)["transplants"]
    .sum()
    .sort_values("transplants", ascending=False)
)
# Out:
# Total transplants by organ:
#                               organ  transplants
# 3                            Kidney       632312
# 5                             Liver       238466
# 0                             Heart       102252
# 6                              Lung        59511
# 4                 Kidney / Pancreas        29596
# 7                          Pancreas         9624
# 2                         Intestine         3655
# 1                      Heart / Lung         1641
# 13                     VCA - uterus           67
# 12                 VCA - upper limb           38
# 10              VCA - head and neck           25
# 8              VCA - abdominal wall           22
# 9     VCA - external male genitalia            2
# 11  VCA - other genitourinary organ            2

# %%
print("\nTotal transplants by donor type:")
display(donor_type_summary)

# 5. Pivot table: donor type vs organ
donor_organ_pivot = df.pivot_table(
    values="transplants",
    index="donor_type",
    columns="organ",
    aggfunc="sum",
    fill_value=0
)
# Out:
# Total transplants by donor type:
#        donor_type  transplants
# 0  Deceased Donor       869225
# 1    Living Donor       207988

# %%
print("\nPivot table: donor type vs organ:")
display(donor_organ_pivot)
# Out:
# Pivot table: donor type vs organ:
# organ            Heart  Heart / Lung  Intestine  Kidney  Kidney / Pancreas  \
# donor_type
# Deceased Donor  102209          1641       3611  435931              29548
# Living Donor        43             0         44  196381                 48
#
# organ            Liver   Lung  Pancreas  VCA - abdominal wall  \
# donor_type
# Deceased Donor  227319  59258      9600                    22
# Living Donor     11147    253        24                     0
#
# organ           VCA - external male genitalia  VCA - head and neck  \
# donor_type
# Deceased Donor                              2                   25
# Living Donor                                0                    0
#
# organ           VCA - other genitourinary organ  VCA - upper limb  \
# donor_type
# Deceased Donor                                2                38
# Living Donor                                  0                 0
#
# organ           VCA - uterus
# donor_type
# ...

# %%
# Final summary
print("""
Summary insights:
- The dataset is structured around donor type, organ category, and transplant counts.
- Organ totals show which transplant categories contribute the largest counts overall.
- Donor type totals compare the relative contribution of each donor source.
- The pivot table makes it easy to compare organ distribution across donor types.
""")
# Out:
# Summary insights:
# - The dataset is structured around donor type, organ category, and transplant counts.
# - Organ totals show which transplant categories contribute the largest counts overall.
# - Donor type totals compare the relative contribution of each donor source.
# - The pivot table makes it easy to compare organ distribution across donor types.

# %%
# Version 2

fig = px.treemap(
    df,
    path=['organ','donor_type'],
    values='transplants',
    color='organ',
    title="U.S. Transplants by Organ and Donor Type"
)

fig.update_layout(
    margin=dict(t=50, l=25, r=25, b=25)
)

fig.write_image("../outputs/treemap_v2.png")

# %%
# Version 3 ; 4 ; 5 

raw_path = "../data/raw/Organ_by_Diagnosis.csv"
processed_dir = Path("../data/processed")
processed_dir.mkdir(parents=True, exist_ok=True)

long_path = processed_dir / "waitlist_organ_by_diagnosis_long.csv"
top_path = processed_dir / "waitlist_organ_by_diagnosis_top.csv"


# Paths
image_path = Path("../outputs/treemap_v6_final.png")
output_dir = Path("../slide")
output_dir.mkdir(parents=True, exist_ok=True)
pptx_path = output_dir / "assignment_03_slide.pptx"



def show_plotly(fig):
    display(HTML(fig.to_html(full_html=False, include_plotlyjs="cdn")))


# Output directory
output_dir = Path("../outputs")
output_dir.mkdir(parents=True, exist_ok=True)

# Muted Life Flow palette
life_flow_palette = {
    "Kidney": "#6f8f72",
    "Liver": "#7c9a92",
    "Heart": "#9c7a7a",
    "Lung": "#c2a878",
    "Pancreas": "#a8b3a1",
    "Heart / Lung": "#5f7a74",
    "Kidney / Pancreas": "#4f6f55",
    "Intestine": "#b8aa8f",
    "VCA - abdominal wall": "#d6c7aa",
    "VCA - external male genitalia": "#d6c7aa",
    "VCA - head and neck": "#d6c7aa",
    "VCA - other genitourinary organ": "#d6c7aa",
    "VCA - upper limb": "#d6c7aa",
    "VCA - uterus": "#d6c7aa",
}

def style_treemap(fig, title):
    fig.update_traces(
        textinfo="label+value+percent root",
        textfont_size=16,
        marker=dict(line=dict(color="white", width=1.2)),
        hovertemplate="<b>%{label}</b><br>Transplants: %{value:,.0f}<br>Share: %{percentRoot:.1%}<extra></extra>",
    )
    fig.update_layout(
        title=dict(text=title, x=0.02, xanchor="left", font=dict(size=22)),
        font=dict(family="Arial, sans-serif", size=14, color="#2f3430"),
        margin=dict(t=60, l=10, r=10, b=10),
        paper_bgcolor="white",
        plot_bgcolor="white",
    )
    return fig

# Version 3: Organ only
fig_v1 = px.treemap(
    df,
    path=["organ"],
    values="transplants",
    color="organ",
    color_discrete_map=life_flow_palette,
)

fig_v1 = style_treemap(
    fig_v1,
    "U.S. Organ Transplants by Organ Type"
)

fig_v1.write_image(output_dir / "treemap_v3_organ_only.png", scale=2)
show_plotly(fig_v1)

# Version 4: Donor type, then organ
fig_v2 = px.treemap(
    df,
    path=["donor_type", "organ"],
    values="transplants",
    color="organ",
    color_discrete_map=life_flow_palette,
)

fig_v2 = style_treemap(
    fig_v2,
    "U.S. Organ Transplants by Donor Type and Organ"
)

fig_v2.write_image(output_dir / "treemap_v4_donor_then_organ.png", scale=2)
show_plotly(fig_v2)

# Version 5: Organ, then donor type
fig_final = px.treemap(
    df,
    path=["organ", "donor_type"],
    values="transplants",
    color="organ",
    color_discrete_map=life_flow_palette,
)

fig_final = style_treemap(
    fig_final,
    "Kidney Transplants Dominate the U.S. Organ Transplant System"
)

fig_final.write_image(output_dir / "treemap_v5_organ_then_donor.png", scale=2)
show_plotly(fig_final)

display(Markdown("""
- Kidney represents the largest share of transplant volume.
- Living donation is concentrated primarily in kidney transplantation.
- Other organ categories depend largely on deceased donation, reinforcing the supply-constrained nature of the system.
"""))
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Version 6: Donor type, then organ - Final

raw_path = "../data/raw/Organ_by_Diagnosis.csv"
processed_dir = Path("../data/processed")
processed_dir.mkdir(parents=True, exist_ok=True)

long_path = processed_dir / "waitlist_organ_by_diagnosis_long.csv"
top_path = processed_dir / "waitlist_organ_by_diagnosis_top.csv"


# Paths
image_path = Path("../outputs/treemap_v6_final.png")
output_dir = Path("../slide")
output_dir.mkdir(parents=True, exist_ok=True)
pptx_path = output_dir / "assignment_03_slide.pptx"



df_v2 = df.copy()

donor_soft_palette = {
    "Deceased Donor": "#5f6662",
    "Living Donor": "#c7c3b8",
}

# Keep organs colored by the Life Flow palette while giving parent donor blocks muted colors
df_v2["treemap_color"] = df_v2["organ"]

fig_v2 = px.treemap(
    df_v2,
    path=["donor_type", "organ"],
    values="transplants",
    color="treemap_color",
    color_discrete_map={
        **life_flow_palette,
        **donor_soft_palette,
    },
)

fig_v2.update_traces(
    marker_colors=[
        donor_soft_palette.get(label, life_flow_palette.get(label, "#b8aa8f"))
        for label in fig_v2.data[0].labels
    ]
)

fig_v2 = style_treemap(
    fig_v2,
    "Cumulative U.S. transplants by donor type and organ, 1988–2025"
)



fig_v2.write_image(output_dir / "../outputs/treemap_v6_final.png", scale=2)
fig_final.write_html(output_dir / "../outputs/treemap_v6_final.html")
show_plotly(fig_v2)
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from pptx import Presentation
from pptx.enum.shapes import MSO_SHAPE
from pptx.util import Inches, Pt


# Colors
bg_color = RGBColor(255, 255, 255)      # #f5f1e8
panel_fill = RGBColor(255, 255, 255)    # #efe7d6
text_color = RGBColor(47, 62, 52)       # #2f3e34

# Create presentation
prs = Presentation()
prs.slide_width = Inches(13.333)
prs.slide_height = Inches(7.5)

slide = prs.slides.add_slide(prs.slide_layouts[6])

# Background
slide.background.fill.solid()
slide.background.fill.fore_color.rgb = bg_color

# Treemap image on left
slide.shapes.add_picture(
    str(image_path),
    Inches(0.35),
    Inches(0.45),
    width=Inches(8.05),
    height=Inches(6.35),
)

# Right insight panel
panel = slide.shapes.add_shape(
    MSO_SHAPE.ROUNDED_RECTANGLE,
    Inches(8.7),
    Inches(0.75),
    Inches(4.15),
    Inches(5.9),
)
panel.fill.solid()
panel.fill.fore_color.rgb = panel_fill
panel.line.color.rgb = panel_fill

# Panel text
text_box = slide.shapes.add_textbox(
    Inches(9.05),
    Inches(1.15),
    Inches(3.45),
    Inches(5.0),
)
tf = text_box.text_frame
tf.clear()
tf.word_wrap = True
tf.margin_left = Inches(0.05)
tf.margin_right = Inches(0.05)

# Header
p = tf.paragraphs[0]
p.text = "Key Insights"
p.font.name = "Aptos Display"
p.font.size = Pt(22)
p.font.bold = True
p.font.color.rgb = text_color
p.space_after = Pt(10)



# Bullets
bullets = [
    "The transplant system is heavily concentrated in kidney procedures.",
    "Living donations contributes meaningfully to kidney transplants.",
    "Living donations contribute a small fraction to overall liver transplants.", 
    "Most other organ transplants depend entirely on deceased donors.",
]

for bullet in bullets:
    p = tf.add_paragraph()
    p.text = bullet
    p.level = 0
    p.font.name = "Aptos"
    p.font.size = Pt(14)
    p.font.color.rgb = text_color
    p.space_after = Pt(14)

# Footer
footer_box = slide.shapes.add_textbox(
    Inches(0.45),
    Inches(7.0),
    Inches(8.5),
    Inches(0.3),
)
footer_tf = footer_box.text_frame
footer_tf.clear()

footer_p = footer_tf.paragraphs[0]
footer_p.text = "Source: Organ Procurement and Transplantation Network (OPTN), 2026."
footer_p.font.name = "Aptos"
footer_p.font.size = Pt(9.5)
footer_p.font.color.rgb = text_color

# Save
prs.save(pptx_path)

pptx_path
# Out:
# PosixPath('../slide/assignment_03_slide.pptx')

# %%
from pathlib import Path
import pandas as pd


ROOT = Path.cwd().parents[1]

raw_path = "../data/raw/Organ_by_Diagnosis.csv"
processed_dir = ROOT / "data" / "processed"
processed_dir.mkdir(parents=True, exist_ok=True)

long_path = processed_dir / "waitlist_organ_by_diagnosis_long.csv"
top_path = processed_dir / "waitlist_organ_by_diagnosis_top.csv"

# Life Flow / Assignment 03 palette basis
ORGAN_COLORS = {
    "Kidney": "#6f8f72",
    "Liver": "#7c9a92",
    "Heart": "#9c7a7a",
    "Lung": "#c2a878",
    "Pancreas": "#a8b3a1",
    "Heart / Lung": "#5f7a74",
    "Kidney / Pancreas": "#4f6f55",
    "Intestine": "#b8aa8f",
    "VCA - abdominal wall": "#d6c7aa",
    "VCA - head and neck": "#d6c7aa",
    "VCA - other genitourinary organ": "#d6c7aa",
    "VCA - upper limb": "#d6c7aa",
    "VCA - uterus": "#d6c7aa",
}

df = pd.read_csv(raw_path)

# Rename the diagnosis column from the export.
df = df.rename(columns={df.columns[0]: "diagnosis"})

# Drop extra blank/unused export column if present.
if "Unnamed: 1" in df.columns:
    df = df.drop(columns=["Unnamed: 1"])

# Convert organ count columns to numeric.
organ_cols = [c for c in df.columns if c != "diagnosis"]
for col in organ_cols:
    df[col] = (
        df[col]
        .astype(str)
        .str.replace(",", "", regex=False)
        .str.strip()
        .replace({"": "0", "nan": "0"})
    )
    df[col] = pd.to_numeric(df[col], errors="coerce").fillna(0).astype(int)

# Remove the aggregate diagnosis row for diagnosis-level analysis.
df_detail = df[df["diagnosis"] != "All Diagnosis"].copy()

# Long format: diagnosis → organ → waitlist count.
long = df_detail.melt(
    id_vars=["diagnosis"],
    value_vars=organ_cols,
    var_name="organ",
    value_name="count",
)

# Remove zero rows and the aggregate organ column.
long = long[(long["count"] > 0) & (long["organ"] != "All Organs")].copy()
long["organ_color"] = long["organ"].map(ORGAN_COLORS).fillna("#d6c7aa")

# Top diagnosis-organ combinations for quick treemap or bar-chart testing.
top = long.sort_values("count", ascending=False).head(40).reset_index(drop=True)

long.to_csv(long_path, index=False)
top.to_csv(top_path, index=False)

print(f"Wrote long dataset: {long_path} ({len(long)} rows)")
print(f"Wrote top exploratory dataset: {top_path} ({len(top)} rows)")
print(top.head(15).to_string(index=False))
# Out:
# Wrote long dataset: /Users/justinlocke/Documents/GitHub/dataunlocked-labs/apps/life_flow/assignments/data/processed/waitlist_organ_by_diagnosis_long.csv (312 rows)
# Wrote top exploratory dataset: /Users/justinlocke/Documents/GitHub/dataunlocked-labs/apps/life_flow/assignments/data/processed/waitlist_organ_by_diagnosis_top.csv (40 rows)
#                                                               diagnosis             organ  count organ_color
#                                            Diabetes Mellitus -. Type II            Kidney  34058     #6f8f72
#                                            Hypertensive Nephrosclerosis            Kidney  17947     #6f8f72
#                                                          Other, Specify            Kidney   9861     #6f8f72
#                                                      Polycystic Kidneys            Kidney   6196     #6f8f72
# ...

# %%
import plotly.express as px

fig = px.treemap(
    top,
    path=['organ', 'diagnosis'],
    values='count',
    color='organ',
    color_discrete_map={
        'Kidney': '#6f8f72',
        'Liver': '#7c9a92',
        'Heart': '#9c7a7a',
        'Lung': '#c2a878',
        'Pancreas': '#a8b3a1',
        'Kidney / Pancreas': '#4f6f55',
        'Heart / Lung': '#5f7a74',
        'Intestine': '#b8aa8f'
    },
    title="Waitlist Demand by Diagnosis and Organ"
)

fig.update_traces(textinfo="label+value+percent entry")

fig.write_html("../outputs/waitlist_treemap.html")

# %%
import pandas as pd

df_tx = pd.read_csv("../data/raw/Transplant___Organ_by_Recipient_Diagnosis.csv")

# Rename first column
df_tx = df_tx.rename(columns={df_tx.columns[0]: "diagnosis"})

# Drop blank export column if present
if "Unnamed: 1" in df_tx.columns:
    df_tx = df_tx.drop(columns=["Unnamed: 1"])

# Convert organ columns from text to numeric
organ_cols = [c for c in df_tx.columns if c != "diagnosis"]

for col in organ_cols:
    df_tx[col] = (
        df_tx[col]
        .astype(str)
        .str.replace(",", "", regex=False)
        .str.strip()
        .replace({"": "0", "nan": "0"})
    )
    df_tx[col] = pd.to_numeric(df_tx[col], errors="coerce").fillna(0).astype(int)

# Long format
tx_long = df_tx.melt(
    id_vars=["diagnosis"],
    value_vars=organ_cols,
    var_name="organ",
    value_name="transplants"
)

# Filter after numeric conversion
tx_long = tx_long[(tx_long["transplants"] > 0) & (tx_long["organ"] != "All Organs")]

tx_long.sort_values("transplants", ascending=False).head(20)
# Out:
#                                diagnosis              organ  transplants
# 32                         All Diagnoses             Kidney        27574
# 64                         All Diagnoses              Liver        12344
# 43                              Diabetes             Kidney         8079
# 86                                 Other              Liver         5605
# 47          Hypertensive Nephrosclerosis             Kidney         5161
# 46                    Glomerular Disease             Kidney         4790
# 160                        All Diagnoses              Heart         4587
# 54                                 Other             Kidney         3749
# 192                        All Diagnoses               Lung         3490
# 70   Cholestatic Liver Disease/Cirrhosis              Liver         3340
# 165                       Cardiomyopathy              Heart         2693
# 60            Retransplant/Graft Failure             Kidney         2017
# ...

# %%
# Demand (waitlist)
demand_diag = (
    long.groupby("diagnosis", as_index=False)["count"]
    .sum()
    .rename(columns={"count": "waitlist"})
)

# Transplants (intersection)
tx_diag = (
    tx_long.groupby("diagnosis", as_index=False)["transplants"]
    .sum()
)

# Merge
compare = demand_diag.merge(tx_diag, on="diagnosis", how="outer").fillna(0)

# Shares
compare["waitlist_share"] = compare["waitlist"] / compare["waitlist"].sum()
compare["tx_share"] = compare["transplants"] / compare["transplants"].sum()

# Difference (over/under representation)
compare["diff"] = compare["tx_share"] - compare["waitlist_share"]

# Keep top diagnoses by demand (readable)
top_compare = compare.sort_values("waitlist", ascending=False).head(20).copy()
top_compare
# Out:
#                                              diagnosis  waitlist  transplants  \
# 90                        Diabetes Mellitus -. Type II   34876.0          0.0
# 137                       Hypertensive Nephrosclerosis   17993.0       5182.0
# 196                                     Other, Specify   10449.0          0.0
# 207                                 Polycystic Kidneys    6202.0       1963.0
# 236                         Retransplant/Graft Failure    6148.0       2203.0
# 89                         Diabetes Mellitus -. Type I    5331.0          0.0
# 188                                       Not Reported    4985.0         74.0
# 116  Focal Glomerular Sclerosis (Focal Segmental -. Fs    4732.0          0.0
# 143                                    Iga Nephropathy    4345.0          0.0
# 264                       Systemic Lupus Erythematosus    2135.0          0.0
# 2    ALCOHOL-ASSOCIATED CIRRHOSIS WITHOUT ACUTE ALC...    2124.0          0.0
# ...

# %%
import plotly.express as px

melted = top_compare.melt(
    id_vars="diagnosis",
    value_vars=["waitlist_share", "tx_share"],
    var_name="type",
    value_name="share"
)

fig = px.bar(
    melted,
    x="diagnosis",
    y="share",
    color="type",
    barmode="group",
    title="Demand vs Transplants by Diagnosis (Share)"
)

fig.update_layout(xaxis_tickangle=45)
fig.write_html("../outputs/diagnosis_demand_vs_transplants.html")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[121], line 22
#      18 # -----------------------
#      19 # Final layout + annotations
#      20 # -----------------------
#      21
# ---> 22 fig.update_layout(...)
#      23 fig.add_annotation(...)
#      24 fig.add_annotation(...)
#      25
#
# File ~/Documents/GitHub/dataunlocked-labs/.venv/lib/python3.13/site-packages/plotly/graph_objs/_figure.py:218, in Figure.update_layout(self, dict1, overwrite, **kwargs)
#     214         BaseFigure
#     215             The Figure object that the update_layout method was called on
#     216
#     217         """
# --> 218         return super().update_layout(dict1, overwrite, **kwargs)
#
# File ~/Documents/GitHub/dataunlocked-labs/.venv/lib/python3.13/site-packages/plotly/basedatatypes.py:1415, in BaseFigure.update_layout(self, dict1, overwrite, **kwargs)
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px

# --- Treemap 1: WAITLIST ---
fig1 = px.treemap(
    long,
    path=['organ', 'diagnosis'],
    values='count',
    color='organ',
    color_discrete_map={
        'Kidney': '#6f8f72',
        'Liver': '#7c9a92',
        'Heart': '#9c7a7a',
        'Lung': '#c2a878',
        'Pancreas': '#a8b3a1',
        'Kidney / Pancreas': '#4f6f55',
        'Heart / Lung': '#5f7a74',
        'Intestine': '#b8aa8f'
    }
)

# --- Treemap 2: TRANSPLANTS ---
fig2 = px.treemap(
    tx_long,
    path=['organ', 'diagnosis'],
    values='transplants',
    color='organ',
    color_discrete_map={
        'Kidney': '#6f8f72',
        'Liver': '#7c9a92',
        'Heart': '#9c7a7a',
        'Lung': '#c2a878',
        'Pancreas': '#a8b3a1',
        'Kidney / Pancreas': '#4f6f55',
        'Heart / Lung': '#5f7a74',
        'Intestine': '#b8aa8f'
    }
)

# --- Create side-by-side layout ---
fig = make_subplots(
    rows=1, cols=2,
    specs=[[{"type": "domain"}, {"type": "domain"}]],
    subplot_titles=("Waitlist Demand by Diagnosis", "Transplants by Diagnosis")
)

# Add traces
for trace in fig1.data:
    fig.add_trace(trace, row=1, col=1)

for trace in fig2.data:
    fig.add_trace(trace, row=1, col=2)

# Clean layout
fig.update_layout(
    title="Demand vs Transplants by Diagnosis",
    margin=dict(t=50, l=10, r=10, b=10)
)

# Save instead of show (safer)
fig.write_html("../outputs/side_by_side_treemaps.html")

# %%
def clean_organ_diagnosis_export(path, value_name):
    df = pd.read_csv(path)

    # First column is diagnosis
    df = df.rename(columns={df.columns[0]: "diagnosis"})

    # Drop blank / unnamed columns
    df = df.drop(columns=[c for c in df.columns if str(c).startswith("Unnamed")], errors="ignore")

    # Clean diagnosis text
    df["diagnosis"] = df["diagnosis"].astype(str).str.strip()

    # IMPORTANT: remove aggregate diagnosis rows
    df = df[
        ~df["diagnosis"].str.lower().isin([
            "all diagnosis",
            "all diagnoses",
            "total",
            "totals",
            "all"
        ])
    ].copy()

    # Drop aggregate / non-organ columns
    df = df.drop(
        columns=[
            c for c in df.columns
            if str(c).strip().lower() in [
                "all organs",
                "all organ",
                "to date",
                "to_date",
                "year",
                "years"
            ]
        ],
        errors="ignore"
    )

    organ_cols = [c for c in df.columns if c != "diagnosis"]

    for col in organ_cols:
        df[col] = (
            df[col]
            .astype(str)
            .str.replace(",", "", regex=False)
            .str.strip()
            .replace({"": "0", "nan": "0", "*": "0"})
        )
        df[col] = pd.to_numeric(df[col], errors="coerce").fillna(0).astype(int)

    long = df.melt(
        id_vars=["diagnosis"],
        value_vars=organ_cols,
        var_name="organ",
        value_name=value_name,
    )

    long["organ"] = long["organ"].astype(str).str.strip()

    long = long[
        (long[value_name] > 0)
        & (long["organ"].str.lower() != "all organs")
        & (~long["diagnosis"].str.lower().isin(["all diagnosis", "all diagnoses", "total", "totals", "all"]))
    ].copy()

    return long

# %%
print(df_tx.columns.tolist())
print(df_tx.head())
print(df_tx.sum(numeric_only=True).sort_values(ascending=False).head(20))
# Out:
# ['diagnosis', 'All Organs', 'Kidney', 'Liver', 'Pancreas', 'Kidney / Pancreas', 'Heart', 'Lung', 'Heart / Lung', 'Intestine', 'VCA - other genitourinary organ', 'VCA - uterus']
#                           diagnosis  All Organs  Kidney  Liver  Pancreas  \
# 0                     All Diagnoses       49065   27574  12344       107
# 1            Acute Hepatic Necrosis         206       0    206         0
# 2  Alpha-1 - Antitrypsin Deficiency          47       0      0         0
# 3                  Benign Neoplasms         144       0    144         0
# 4                   Biliary Atresia         229       0    229         0
#
#    Kidney / Pancreas  Heart  Lung  Heart / Lung  Intestine  \
# 0                804   4587  3490            61         88
# 1                  0      0     0             0          0
# 2                  0      0    47             0          0
# 3                  0      0     0             0          0
# ...

# %%
df_tx = df_tx[df_tx["diagnosis"].astype(str).str.strip() != "All Diagnosis"]

drop_cols = [
    c for c in df_tx.columns
    if c in ["All Organs", "To Date", "to_date", "Year", "year"]
    or str(c).startswith("Unnamed")
]

df_tx = df_tx.drop(columns=drop_cols, errors="ignore")

# %%
import pandas as pd

# Load file (adjust path if needed)
df_wait = pd.read_csv("../data/raw/Organ_by_Diagnosis.csv")

# Rename first column → diagnosis
df_wait = df_wait.rename(columns={df_wait.columns[0]: "diagnosis"})

# Drop junk columns
df_wait = df_wait.drop(columns=[c for c in df_wait.columns if "Unnamed" in str(c)], errors="ignore")

# Clean diagnosis
df_wait["diagnosis"] = df_wait["diagnosis"].astype(str).str.strip()

# Remove aggregate rows
df_wait = df_wait[~df_wait["diagnosis"].str.lower().isin(["all diagnosis", "total", "all"])]

# Drop aggregate columns
df_wait = df_wait.drop(columns=[c for c in df_wait.columns if "All Organs" in str(c)], errors="ignore")

# Convert numbers
for col in df_wait.columns:
    if col != "diagnosis":
        df_wait[col] = (
            df_wait[col]
            .astype(str)
            .str.replace(",", "", regex=False)
            .str.strip()
            .replace({"": "0", "nan": "0", "*": "0"})
        )
        df_wait[col] = pd.to_numeric(df_wait[col], errors="coerce").fillna(0)

# Melt to long format
wait_long = df_wait.melt(
    id_vars="diagnosis",
    var_name="organ",
    value_name="waitlist_count"
)

# Filter
wait_long = wait_long[
    (wait_long["waitlist_count"] > 0) &
    (wait_long["organ"].str.lower() != "all organs")
]

print("wait_long ready")
print(wait_long.head())
# Out:
# wait_long ready
#                                             diagnosis   organ  waitlist_count
# 3                 Drug Related Interstitial Nephritis  Kidney             144
# 7                                     Fabry'S Disease  Kidney              48
# 10                               Familial Nephropathy  Kidney              28
# 17  Focal Glomerular Sclerosis (Focal Segmental -. Fs  Kidney            4728
# 18                             Goodpasture'S Syndrome  Kidney              87

# %%
# REbuild df_tx

df_tx = pd.read_csv("../data/raw/Transplant___Organ_by_Recipient_Diagnosis.csv")

df_tx = df_tx.rename(columns={df_tx.columns[0]: "diagnosis"})
df_tx = df_tx.drop(columns=[c for c in df_tx.columns if "Unnamed" in str(c)], errors="ignore")

df_tx["diagnosis"] = df_tx["diagnosis"].astype(str).str.strip()
df_tx = df_tx[~df_tx["diagnosis"].str.lower().isin(["all diagnosis", "total", "all"])]

df_tx = df_tx.drop(columns=[c for c in df_tx.columns if "All Organs" in str(c)], errors="ignore")

for col in df_tx.columns:
    if col != "diagnosis":
        df_tx[col] = (
            df_tx[col]
            .astype(str)
            .str.replace(",", "", regex=False)
            .str.strip()
            .replace({"": "0", "nan": "0", "*": "0"})
        )
        df_tx[col] = pd.to_numeric(df_tx[col], errors="coerce").fillna(0)

tx_long = df_tx.melt(
    id_vars="diagnosis",
    var_name="organ",
    value_name="transplants"
)

tx_long = tx_long[
    (tx_long["transplants"] > 0) &
    (tx_long["organ"].str.lower() != "all organs")
]

print("tx_long ready")
# Out:
# tx_long ready

# %%
# -----------------------
# Combine side-by-side, scaled by total size
# -----------------------

from plotly.subplots import make_subplots


wait_total = wait_long["waitlist_count"].sum()
tx_total = tx_long["transplants"].sum()



wait_total = wait_long["waitlist_count"].sum()
tx_total = tx_long["transplants"].sum()

fig_wait = px.treemap(
    wait_long,
    path=["organ", "diagnosis"],
    values="waitlist_count",
    color="organ",
    color_discrete_map=ORGAN_COLORS,
)

fig_tx = px.treemap(
    tx_long,
    path=["organ", "diagnosis"],
    values="transplants",
    color="organ",
    color_discrete_map=ORGAN_COLORS,
)

fig = make_subplots(
    rows=1,
    cols=2,
    specs=[[{"type": "domain"}, {"type": "domain"}]],
    subplot_titles=(
        f"Current Waitlist Demand<br>{wait_total:,.0f} registrations",
        f"2025 Transplants<br>{tx_total:,.0f} transplants"
    ),
    column_widths=[wait_total, tx_total],
    horizontal_spacing=0.04
)

for trace in fig_wait.data:
    fig.add_trace(trace, row=1, col=1)

for trace in fig_tx.data:
    fig.add_trace(trace, row=1, col=2)

fig.update_traces(textinfo="label+value+percent entry")

fig.update_layout(
    title="Demand vs Transplants by Organ and Diagnosis",
    margin=dict(t=90, l=10, r=10, b=10),
    paper_bgcolor="#f5f1e8",
    plot_bgcolor="#f5f1e8",
    font=dict(color="#2f3e34"),
)

fig.write_html("../outputs/waitlist_vs_2025_transplants_scaled_treemaps.html")

try:
    fig.write_image("../outputs/waitlist_vs_2025_transplants_scaled_treemaps.png")
except Exception as e:
    print("HTML saved. PNG export failed:")
    print(e)
    
    
    
    # -----------------------
# Final layout + annotations
# -----------------------

fig.update_layout(
    title="Demand vs Transplants by Organ and Diagnosis",
    title_x=0.5,
    margin=dict(t=90, l=10, r=10, b=40),
    paper_bgcolor="#f5f1e8",
    plot_bgcolor="#f5f1e8",
    font=dict(family="Arial, sans-serif", size=12, color="#2f3e34"),
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=-0.15,
        xanchor="center",
        x=0.5,
    ),
)

fig.add_annotation(
    text="Sizes are scaled by panel totals; waitlist registrations vs 2025 transplants.",
    x=0.5,
    y=-0.05,
    xref="paper",
    yref="paper",
    showarrow=False,
    font=dict(size=12, color="#2f3e34"),
)

fig.add_annotation(
    text="Organ > diagnosis hierarchy shown in each treemap.",
    x=0.5,
    y=-0.11,
    xref="paper",
    yref="paper",
    showarrow=False,
    font=dict(size=11, color="#2f3e34"),
)
fig.update_layout(
    title="Demand vs Transplants by Organ and Diagnosis",
    title_x=0.5,
    margin=dict(t=90, l=10, r=10, b=40),
    paper_bgcolor="#f5f1e8",
    plot_bgcolor="#f5f1e8",
    font=dict(family="Arial, sans-serif", size=12, color="#2f3e34"),
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=-0.15,
        xanchor="center",
        x=0.5,
    ),
)

fig.add_annotation(
    text="Sizes are scaled by panel totals; waitlist registrations vs 2025 transplants.",
    x=0.5,
    y=-0.05,
    xref="paper",
    yref="paper",
    showarrow=False,
    font=dict(size=12, color="#2f3e34"),
)

fig.add_annotation(
    text="Organ > diagnosis hierarchy shown in each treemap.",
    x=0.5,
    y=-0.11,
    xref="paper",
    yref="paper",
    showarrow=False,
    font=dict(size=11, color="#2f3e34"),
)
fig.update_layout(
    title="Demand vs Transplants by Organ and Diagnosis",
    title_x=0.5,
    margin=dict(t=90, l=10, r=10, b=40),
    paper_bgcolor="#f5f1e8",
    plot_bgcolor="#f5f1e8",
    font=dict(family="Arial, sans-serif", size=12, color="#2f3e34"),
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=-0.15,
        xanchor="center",
        x=0.5,
    ),
    annotations=[
        dict(
            text="Sizes are scaled by panel totals; waitlist registrations vs 2025 transplants.",
            x=0.5,
            y=-0.05,
            xref="paper",
            yref="paper",
            showarrow=False,
            font=dict(size=12, color="#2f3e34"),
        ),
        dict(
            text="Organ > diagnosis hierarchy shown in each treemap.",
            x=0.5,
            y=-0.11,
            xref="paper",
            yref="paper",
            showarrow=False,
            font=dict(size=11, color="#2f3e34"),
        ),
    ],
)

# -----------------------
# SAVE OUTPUTS
# -----------------------

# HTML (interactive)
fig.write_html("../outputs/waitlist_vs_2025_transplants_scaled_treemaps.html")

# SVG (for Word / PDF — THIS is Option 2)
fig.write_image("../outputs/waitlist_vs_2025_transplants_scaled_treemaps.svg")

# %%
def classify_diagnosis(d):
    d = str(d).lower()

    # Chronic
    if any(x in d for x in [
        "diabetes",
        "hypertensive",
        "nephro",
        "cirrhosis",
        "mash",
        "lupus"
    ]):
        return "Chronic Disease"

    # Genetic / congenital
    if any(x in d for x in [
        "polycystic",
        "genetic",
        "congenital"
    ]):
        return "Genetic / Congenital"

    # Acute
    if any(x in d for x in [
        "acute",
        "trauma",
        "failure"
    ]):
        return "Acute / Sudden"

    return "Other"

# %%
wait_long["diagnosis_group"] = wait_long["diagnosis"].apply(classify_diagnosis)
tx_long["diagnosis_group"] = tx_long["diagnosis"].apply(classify_diagnosis)

# %%
wait_grouped = wait_long.groupby(
    ["organ", "diagnosis_group"], as_index=False
)["waitlist_count"].sum()

tx_grouped = tx_long.groupby(
    ["organ", "diagnosis_group"], as_index=False
)["transplants"].sum()

# %%
path=["organ", "diagnosis_group"]
