# %% [markdown]
# # Assignment 05 — Spatial Data
#
# ## Current Hypothesis
# The transplant system appears regionally concentrated but nationally connected.
#
# ## Core Dataset
# D2T donor recovery → transplant center flows.
#
# ## Current Findings
# - Strongest flows are often intra-state.
# - National network less dense than expected.
# - Flow maps may work better as regional or organ-specific small multiples.

# %%
from pathlib import Path
import pandas as pd

BASE = Path("../data/processed")

edges = pd.read_csv(BASE / "d2t_edges_all_organs_enriched.csv")

edges.head()
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel '.venv (Python 3.13.2)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # 1. Assignment Goal
# # 2. Data Sources
# # 3. Raw Data Inventory
# # 4. Core Flow Dataset
# # 5. Reference Lookups
# # 6. Edge Distribution / Threshold Tests
# # 7. Visual Iterations
# # 8. Design Decisions
# # 9. Candidate Final Slide
